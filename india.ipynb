# %%
import pandas as pd

# %%
df= pd.read_csv('india.csv')
df
# Out:
#        num         domain_name           query_time create_date update_date  \
# 0        1           0ff.store  2021-02-02 15:06:56  2021-01-30  2021-01-30
# 1        2          12mqch.com  2021-02-02 15:51:56  2021-01-31  2021-01-31
# 2        3    1moviesdrama.xyz  2021-02-02 14:49:08  2021-01-31         NaN
# 3        4       24roundup.com  2021-02-02 14:21:35  2021-01-31  2021-01-31
# 4        5  24voiceofindia.com  2021-02-02 15:51:47  2021-01-31  2021-01-31
# ...    ...                 ...                  ...         ...         ...
# 2325  2326          zightn.com  2021-02-02 15:30:20  2021-01-31  2021-01-31
# 2326  2327          ziivan.com  2021-02-02 16:03:30  2021-01-31  2021-01-31
# 2327  2328    zindagihindi.com  2021-02-02 15:30:19  2021-01-31  2021-01-31
# 2328  2329          zrocks.xyz  2021-02-02 14:52:10  2021-01-31  2021-01-31
# 2329  2330          zukelo.com  2021-02-02 14:20:28  2021-01-31  2021-01-31
#
#      expiry_date  domain_registrar_id                   domain_registrar_name  \
# 0     2022-01-30               1636.0                          Hostinger, UAB
# 1     2022-01-31                146.0                        GoDaddy.com, LLC
# 2     2022-01-31               1479.0                           Namesilo, LLC
# 3     2022-01-31               1647.0  Hosting Concepts B.V. dba Openprovider
# 4     2022-01-31                146.0                        GoDaddy.com, LLC
# ...          ...                  ...                                     ...
# 2325  2022-01-31               1495.0                  BigRock Solutions Ltd.
# 2326  2023-01-31                146.0                        GoDaddy.com, LLC
# 2327  2022-01-31                146.0                        GoDaddy.com, LLC
# 2328  2022-01-31                146.0                        GoDaddy.com, LLC
# 2329  2022-01-31               1647.0  Hosting Concepts B.V. dba Openprovider
#
#      domain_registrar_whois          domain_registrar_url  ... billing_phone  \
# 0       whois.hostinger.com      http://www.hostinger.com  ...           NaN
# 1         whois.godaddy.com  http://registrar.godaddy.com  ...           NaN
# 2        whois.namesilo.com       http://www.namesilo.com  ...           NaN
# 3        whois.registrar.eu   http://www.openprovider.com  ...           NaN
# 4         whois.godaddy.com  http://registrar.godaddy.com  ...           NaN
# ...                     ...                           ...  ...           ...
# 2325      whois.bigrock.com        http://www.bigrock.com  ...           NaN
# 2326      whois.godaddy.com  http://registrar.godaddy.com  ...           NaN
# 2327      whois.godaddy.com  http://registrar.godaddy.com  ...           NaN
# 2328      whois.godaddy.com  http://registrar.godaddy.com  ...           NaN
# 2329     whois.registrar.eu   http://www.openprovider.com  ...           NaN
#
#      billing_fax           name_server_1           name_server_2  \
# 0            NaN     ns1.dns-parking.com     ns2.dns-parking.com
# 1            NaN  ns77.domaincontrol.com  ns78.domaincontrol.com
# 2            NaN       ns1.hostcpanel.me       ns2.hostcpanel.me
# 3            NaN     ns1.dns-parking.com     ns2.dns-parking.com
# 4            NaN     ns1.dns-parking.com     ns2.dns-parking.com
# ...          ...                     ...                     ...
# 2325         NaN         dns1.bigrock.in         dns2.bigrock.in
# 2326         NaN  ns33.domaincontrol.com  ns34.domaincontrol.com
# 2327         NaN       ns1.herohosty.xyz       ns2.herohosty.xyz
# 2328         NaN  ns01.domaincontrol.com  ns02.domaincontrol.com
# 2329         NaN     ns1.dns-parking.com     ns2.dns-parking.com
#
#         name_server_3    name_server_4           domain_status_1  \
# 0                 NaN              NaN                 addPeriod
# 1                 NaN              NaN    clientDeleteProhibited
# 2                 NaN              NaN                 addPeriod
# 3                 NaN              NaN  clientTransferProhibited
# 4                 NaN              NaN    clientDeleteProhibited
# ...               ...              ...                       ...
# 2325  dns3.bigrock.in  dns4.bigrock.in  clientTransferProhibited
# 2326              NaN              NaN    clientDeleteProhibited
# 2327              NaN              NaN    clientDeleteProhibited
# 2328              NaN              NaN                 addPeriod
# 2329              NaN              NaN  clientTransferProhibited
#
#                domain_status_2           domain_status_3  \
# 0     clientTransferProhibited  serverTransferProhibited
# 1        clientRenewProhibited  clientTransferProhibited
# 2     clientTransferProhibited  serverTransferProhibited
# 3                           ok                       NaN
# 4        clientRenewProhibited  clientTransferProhibited
# ...                        ...                       ...
# 2325                       NaN                       NaN
# 2326     clientRenewProhibited  clientTransferProhibited
# 2327     clientRenewProhibited  clientTransferProhibited
# 2328    clientDeleteProhibited     clientRenewProhibited
# 2329                        ok                       NaN
#
#                domain_status_4
# 0                          NaN
# 1       clientUpdateProhibited
# 2                          NaN
# 3                          NaN
# 4       clientUpdateProhibited
# ...                        ...
# 2325                       NaN
# 2326    clientUpdateProhibited
# 2327    clientUpdateProhibited
# 2328  clientTransferProhibited
# 2329                       NaN
#
# [2330 rows x 58 columns]

# %%
list(df.columns.values)
# Out:
# ['num',
#  'domain_name',
#  'query_time',
#  'create_date',
#  'update_date',
#  'expiry_date',
#  'domain_registrar_id',
#  'domain_registrar_name',
#  'domain_registrar_whois',
#  'domain_registrar_url',
#  'registrant_name',
#  'registrant_company',
#  'registrant_address',
#  'registrant_city',
#  'registrant_state',
#  'registrant_zip',
#  'registrant_country',
#  'registrant_email',
#  'registrant_phone',
#  'registrant_fax',
#  'administrative_name',
#  'administrative_company',
#  'administrative_address',
#  'administrative_city',
#  'administrative_state',
#  'administrative_zip',
#  'administrative_country',
#  'administrative_email',
#  'administrative_phone',
#  'administrative_fax',
#  'technical_name',
#  'technical_company',
#  'technical_address',
#  'technical_city',
#  'technical_state',
#  'technical_zip',
#  'technical_country',
#  'technical_email',
#  'technical_phone',
#  'technical_fax',
#  'billing_name',
#  'billing_company',
#  'billing_address',
#  'billing_city',
#  'billing_state',
#  'billing_zip',
#  'billing_country',
#  'billing_email',
#  'billing_phone',
#  'billing_fax',
#  'name_server_1',
#  'name_server_2',
#  'name_server_3',
#  'name_server_4',
#  'domain_status_1',
#  'domain_status_2',
#  'domain_status_3',
#  'domain_status_4']

# %%
df['technical_email'].str.findall('(\S+@\S+)')
df['administrative_email'].str.findall('(\S+@\S+)')
df['registrant_email'].str.findall('(\S+@\S+)')
df[['technical_email','administrative_email',"registrant_email"]].dropna(axis=0, how="any")
# Out:
#                     technical_email         administrative_email  \
# 12           [amitavasah@gmail.com]         amitavasah@gmail.com
# 13       [omnidomains@justdial.com]     omnidomains@justdial.com
# 35          [shivaclinic@gmail.com]        shivaclinic@gmail.com
# 37            [webmaster@adani.com]          webmaster@adani.com
# 38            [webmaster@adani.com]          webmaster@adani.com
# ...                             ...                          ...
# 2289  [parasmanigroups@hotmail.com]  parasmanigroups@hotmail.com
# 2292   [ranveerrathore19@gmail.com]   ranveerrathore19@gmail.com
# 2296        [chbhaskar@hotmail.com]        chbhaskar@hotmail.com
# 2320     [info.zedtronic@gmail.com]     info.zedtronic@gmail.com
# 2325       [zibranshaikh@ymail.com]       zibranshaikh@ymail.com
#
#                  registrant_email
# 12           amitavasah@gmail.com
# 13       omnidomains@justdial.com
# 35          shivaclinic@gmail.com
# 37            webmaster@adani.com
# 38            webmaster@adani.com
# ...                           ...
# 2289  parasmanigroups@hotmail.com
# 2292   ranveerrathore19@gmail.com
# 2296        chbhaskar@hotmail.com
# 2320     info.zedtronic@gmail.com
# 2325       zibranshaikh@ymail.com
#
# [367 rows x 3 columns]

# %%
df['billing_email'].values.tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
df['technical_email'].str.findall('(\S+@\S+)')
df['administrative_email'].str.findall('(\S+@\S+)')
df['registrant_email'].str.findall('(\S+@\S+)')
data=df[['technical_email','administrative_email',"registrant_email"]].dropna(axis=0, how="any")
data
# Out:
#                     technical_email         administrative_email  \
# 12           [amitavasah@gmail.com]         amitavasah@gmail.com
# 13       [omnidomains@justdial.com]     omnidomains@justdial.com
# 35          [shivaclinic@gmail.com]        shivaclinic@gmail.com
# 37            [webmaster@adani.com]          webmaster@adani.com
# 38            [webmaster@adani.com]          webmaster@adani.com
# ...                             ...                          ...
# 2289  [parasmanigroups@hotmail.com]  parasmanigroups@hotmail.com
# 2292   [ranveerrathore19@gmail.com]   ranveerrathore19@gmail.com
# 2296        [chbhaskar@hotmail.com]        chbhaskar@hotmail.com
# 2320     [info.zedtronic@gmail.com]     info.zedtronic@gmail.com
# 2325       [zibranshaikh@ymail.com]       zibranshaikh@ymail.com
#
#                  registrant_email
# 12           amitavasah@gmail.com
# 13       omnidomains@justdial.com
# 35          shivaclinic@gmail.com
# 37            webmaster@adani.com
# 38            webmaster@adani.com
# ...                           ...
# 2289  parasmanigroups@hotmail.com
# 2292   ranveerrathore19@gmail.com
# 2296        chbhaskar@hotmail.com
# 2320     info.zedtronic@gmail.com
# 2325       zibranshaikh@ymail.com
#
# [367 rows x 3 columns]

# %%
data.to_csv('dat.csv')
